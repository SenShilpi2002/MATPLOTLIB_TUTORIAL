# %% [markdown]
# # BAR PLOT

# %%
import matplotlib.pyplot as plt
x=["python","c","java","cpp"]
y=[65,99,85,84]
plt.xlabel("language",fontsize=15)
plt.ylabel("no.",fontsize=15)
c=["y","b","r","g"]
plt.title("python")
plt.bar(x,y,color=c,alpha=1)
plt.show()
